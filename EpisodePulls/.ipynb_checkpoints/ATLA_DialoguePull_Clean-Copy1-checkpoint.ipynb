# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

#optional setting 
pd.set_option('display.max_rows', 150)

# %%
season_episode_list =[]

for season in range(1,4):
    if season != 3:
        for episode in range(1,21):
            ep_num = str(episode)
            if len(ep_num) <= 1:
                ep_num = str(0)+ep_num
            else: 
                ep_num
            se_ep = str(season) + ep_num
            season_episode_list.append(se_ep)
    else:
        for episode in range(1,22):
            ep_num = str(episode)
            if len(ep_num) <= 1:
                ep_num = str(0)+ep_num
            else: 
                ep_num
            se_ep = str(season) + ep_num
            season_episode_list.append(se_ep)

# %%
season_episode_list

# %%
def getTitle(x):
    url_base = 'http://atla.avatarspirit.net/transcripts.php?num='
    season_episode_num = str(x) # in a function make this x
    response = requests.get(url_base + season_episode_num)
    
    #
    soup = BeautifulSoup(response.content, 'lxml')
    content = soup.find(class_='content')
    title = content.find(class_='welcome')
    title = title.get_text()
    title = title.split("-")[-1].strip()
    #print(title)
    return(title)

# %%
df = pd.DataFrame(columns = ['SeasonEpisodeCode','Title'])

# %%
#populate a df with SeasonEpisodeCodes & Titles
title_list = []
for x in season_episode_list:
    title_list.append(getTitle(x))

# %%
#creation of df frame
df['SeasonEpisodeCode'] = season_episode_list
df['Title'] = title_list

df['Season'] = df['SeasonEpisodeCode']
df['EpisodeNum'] = df['SeasonEpisodeCode']

#obtain season#
def seasonNum(x):
    return(int(str(x)[0]))
#apply SeasonNum to df
df['Season'] = df['Season'].apply(seasonNum)

#obtain episode #
def episodeNum(x):
    return(int(str(x)[-2:]))
#apply EpisodeNum to df
df['EpisodeNum'] = df['EpisodeNum'].apply(episodeNum)

# %%
df

# %%
#get episode text for cleaning
def RawScriptPull(x):
    url_base = 'http://atla.avatarspirit.net/transcripts.php?num='
    season_episode_num = str(x) # in a function make this x
    response = requests.get(url_base + season_episode_num)
    
    episode_code = x
    
    soup = BeautifulSoup(response.content, 'lxml')
    content = soup.find(class_='content')
    raw_script = content.find(class_='content')
    
    #extracts all text in italics - which are stage directions
    for linebreak in raw_script.find_all('i'):
        linebreak.extract()
    
    #extracts all for hyperlinks - which we don't need
    for linebreak in raw_script.find_all('a'):
        linebreak.extract()
    
    #extracts all the breaks
    for linebreak in raw_script.find_all('br'):
        linebreak.extract()
    #leaves us only the bolds... which we can seperate items on
    raw_script = str(raw_script)
    return([episode_code, raw_script])
    
    #file = open(str(x) + ".txt","w")
    #file.write(str(script))

# %%
#creating a function to clean the script
#then puts it into a data frame
#and counts the number of words each character says

def scriptClean(script_info):
    #episode_code = locals()
    
    episode_code = script_info[0]
    raw_script = script_info[1]
    
    file_clean = re.sub(r'\([^()]*\)', '', raw_script) #need to better understand how reGex Works
    
    #removes data after the Ending Credits which is extra
    script = file_clean.split('[End Credits]')[0]

    #removes the data before Act I, which is also extra
    #unfortunetly, website uses 2 different conventions, so I split depending on which one it uses
    
    if "Act I</b></u>" in script:
        script_clean = script.split("Act I</b></u>")[1]
        #bold_split = script_clean.split('<b>')
    elif "Act I</u></b>" in script:
        script_clean = script.split("Act I</u></b>")[1]
        #bold_split = script_clean.split('<b>')
    
    #needed for episodes 212
    elif "Act I </u></b>" in script:
        script_clean = script.split("Act I </u></b>")[1]
        
        
    #return(script_clean)
    bold_split = script_clean.split('<b>')
    
    #creates a list of lists with both character + relevant dialogue
    master_list = []
    for x in range(len(bold_split)):
        output = bold_split[x].split(':')
        master_list.append(output)
    
    #collects all the characters who speak
    character_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            character_list.append(test.strip('</b>')) # remove the bold hyperlink to cleanup the data
    #collects what all the characters say
    dialogue_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            dialogue_list.append(holder[1].strip('</b>')) # remove the bold hyperlink to cleanup the data 
    
    
    #create a list of episode numbers to add to df (feels inefficient and should be a better way to do this)
    episode_list = []
    
    for x in range(len(character_list)):
       episode_list.append(episode_code)
    
    dfScript = pd.DataFrame()
    
    #dfScript['episode_code'] = episode_list
    dfScript['episode_code'] = episode_list
    
    dfScript['character_list'] = character_list
    dfScript['dialogue_list'] = dialogue_list
    
    count = dfScript['dialogue_list'].str.split().str.len()
    count = list(count)
    dfScript['word_count']=count

    return(dfScript)

# %%
def scriptCleanTalesofBaSingSe(script_info):
    episode_code = script_info[0]
    raw_script = script_info[1]
    
    file_clean = re.sub(r'\([^()]*\)', '', raw_script) #references RawScriptPull so it can get cleaned 
    
    script = file_clean.split('[End Credits]')[0]
    
    #removes last story of Be Sing Se
    #as 'The Tale of Momo' doesn't have any dialogue in it
    script = script.split('<b><u>The Tale of Momo</u>')[0] 
    
    #takes individual stories and combines them into a single variable
    
    #Toph_Katara
    Toph_Katara = script.split('Written by: Joann Estoesta and Lisa Wahlander')[1]
    Toph_Katara = Toph_Katara.split('<b><u>The Tale of Iroh</u></b>')[0]
    
    #Iroh
    
    Iroh = script.split('<b><u>The Tale of Iroh</u></b>Written by: Andrew Huebner')[1]
    Iroh = Iroh.split('<b><u>The Tale of Aang')[0]
    
    #Aang
    
    Aang = script.split('<b><u>The Tale of Aang</u></b>Written by: Gary Scheppke')[1]
    Aang = Aang.split('<b><u>The Tale of Sokka</u></b>Written by: Lauren Macmullan')[0]
    
    #Sokka
    
    Sokka = script.split('<b><u>The Tale of Sokka</u></b>Written by: Lauren Macmullan')[1]
    Sokka = Sokka.split('<b><u>The Tale of Zuko</u></b>Written by: Andrew Huebne')[0]
    
    #Zuko
    #as last bit, don't need any code to cut it off
    Zuko = script.split('<b><u>The Tale of Zuko</u></b>Written by: Andrew Huebne')[1]
    
    BaSingSeScript = Toph_Katara + Iroh + Aang + Sokka + Zuko
    
    #
    bold_split = BaSingSeScript.split('<b>')
    
    #creates a list of lists with both character + relevant dialogue
    master_list = []
    for x in range(len(bold_split)):
        output = bold_split[x].split(':')
        master_list.append(output)
    
    #collects all the characters who speak
    character_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            character_list.append(test.strip('</b>')) # remove the bold hyperlink to cleanup the data
    #collects what all the characters say
    dialogue_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            dialogue_list.append(holder[1].strip('</b>')) # remove the bold hyperlink to cleanup the data 
    
    episode_list = []
    
    for x in range(len(character_list)):
       episode_list.append(215)
    
    dfScript = pd.DataFrame() 
    
    dfScript['episode_code'] = episode_list
    
    dfScript['character_list'] = character_list
    dfScript['dialogue_list'] = dialogue_list
    
    count = dfScript['dialogue_list'].str.split().str.len()
    count = list(count)
    dfScript['word_count']=count
    
    
    return(dfScript)

# %%
#scriptCleanTalesofBaSingSe(RawScriptPull(215))

# %%
def dfConsolidateScript(dfScript):

    #dfScript = scriptClean(x)
    
    i = 1

    dfScriptFinal = pd.DataFrame()
    dfScriptFinal = dfScriptFinal.append(dfScript.iloc[0]) #return another function

    while i < len(dfScript.index):
        if dfScript['character_list'][i] == dfScript['character_list'][i-1]: 

            #consolidates the word count into a single value when the same characters speaks twice in a row
            word_count_consolidate = (dfScript['word_count'][i]+dfScript['word_count'][i-1])
            dfScriptFinal['word_count'].at[i-1] = word_count_consolidate 

            #consolidates the dialogue when the same character speaks twice in a row
            dialogue_consolidate = (dfScript['dialogue_list'][i]+ " " + dfScript['dialogue_list'][i-1])
            dfScriptFinal['dialogue_list'].at[i-1] = dialogue_consolidate 

            i = i + 1
        else:
            dfScriptFinal = dfScriptFinal.append(dfScript.iloc[i])
            i = i + 1
    dfScriptFinal['episode_code'] = dfScriptFinal['episode_code'].astype(int)
    return(dfScriptFinal)

# %%
#example of passing a functin to another function. Working better? Looks like it!
#dfConsolidateScript(scriptClean(RawScriptPull(215)))

# %%
season_episode_list.remove('215') #removes Tales of Ba Sing Se

# %%
# can't get list comprehension to work 
#string vs. int is why list comp wasn't working 

#season_episode_list = [e for e in season_episode_list if e not in to_remove]

# %%
#to_skip = (212,215) #(understand what's going on with 212 & 215)

#trimmed_episode_list = []
#for i in season_episode_list:
 #   if int(i) not in to_remove: #season_episode_list is currently strings. Switched to int
  #      trimmed_episode_list.append(i)

# %%
df_list_holder = []

for i in season_episode_list:
    #print(i)
    df_episode = dfConsolidateScript(scriptClean(RawScriptPull(i)))
    df_list_holder.append(df_episode)

df_master = pd.concat(df_list_holder)
df_master.reset_index(drop = True, inplace = True)

# %%
df_master.tail()
# Out:
#      character_list                                      dialogue_list  \
# 9198            Mai                                I look like a man.
# 9199           Suki             And why did you paint me firebending?
# 9200          Sokka   Oh, you  think you can do a better job, Momo?...
# 9201           Iroh   Hey,  my belly's not that big anymore,  I've ...
# 9202           Toph               Well, I think  you all look perfect!
#
#       episode_code  word_count
# 9198           321         5.0
# 9199           321         7.0
# 9200           321        18.0
# 9201           321        11.0
# 9202           321         7.0

# %%
df_215 = dfConsolidateScript(scriptCleanTalesofBaSingSe(RawScriptPull(215)))

# %%
df_215

# %%
#combines episodes 215
df_final = df_master.append(df_215)

# %%
df_final

# %%
df_final.columns

# %%
#Give the index a name
df_final.index.name = 'MyIndex'

# %%
df_final.sort_values("episode_code")

# %%
df_final.sort_values(['episode_code','MyIndex'],ascending = True,inplace = True)

#info on how to sorty by both column and index
#https://stackoverflow.com/questions/20277358/sort-pandas-dataframe-both-on-values-of-a-column-and-index

# %%
df_final[df_final.episode_code == 215] #.sort_values(by = 'MyIndex')
# Out:
#             character_list                                      dialogue_list  \
# MyIndex
# 0                   Katara   Huh! Toph, aren't you gonna to get ready for ...
# 1                     Toph                                         I'm ready.
# 2                   Katara   You're not gonna wash up? You've got a little...
# 3                     Toph   You call it dirt. I call it a healthy coating...
# 4                   Katara     Hmmm. You know what we need? A girl's day out!
# 5                     Toph                                          Do I  to?
# 6                   Katara                                      It'll be fun.
# 7                     Toph   The Fancy Lady Day Spa? Sounds like my kinda ...
# 8                   Katara          Are you ready for some serious pampering?
# 9                     Toph   Arrrr! Rrrrr! Errrr!  Sure Katara, whatever y...
# 11         Toph and Katara                                            Hahaha!
# 12                    Toph   Well, that wasn't so bad. I'm not usually int...
# 13                  Katara    I'm glad, it's about time we did something f...
# 14           1st Mean Girl                                Wow, great makeup.
# 15                    Toph                                            Thanks.
# 16           1st Mean Girl                                       For a clown!
# 17                  Katara     Don't listen to them, let's just keep walking.
# 18                    Star   I think she looks cute. Like that time we put...
# 19           3rd Mean Girl                                    Good one, Star!
# 20                  Katara                                     Let's go Toph.
# 21                    Toph   No, no. That  a good one! "Like your poodle-m...
# 22                   Girls                                              Ahhh!
# 23                  Katara   Those girls don't know what they're talking a...
# 25                    Toph   It's ok. One of the good things about being b...
# 26                  Katara   That's what I really admire about you, Toph. ...
# 27                    Toph                                              I am?
# 28                  Katara                                     Yeah. You are.
# 29                    Toph   I'd return the compliment, but I have no idea...
# 30                  Katara
# 31                    Toph                                Thank you, Katara.
# 32                  Katara                                                Ow!
# 33                Merchant   If this is for a romantic picnic, may I sugge...
# 34                    Iroh   No, it is not a romantic picnic, but it is a ...
# 35                   Child                                              Wahh!
# 36                   Woman                               Shhh. It's ok. Shhh.
# 37                    Iroh   Yeowch!  Leaves from the vine, falling so slo...
# 39                   Child                                            Hahaha!
# 40               Angry Man                                               Hey!
# 41                    Iroh   It is usually best to admit mistakes when the...
# 42               Angry Man   When I am through with you kids, the window w...
# 43                    Iroh                           -but not this time. Run!
# 44                  Mugger                       You. Give me all your money!
# 45                    Iroh                                What are you doing?
# 46                  Mugger                                   I'm mugging you!
# 47                    Iroh                                  With that stance?
# 48                  Mugger   Wha- What are you talking about? Just give me...
# 49                    Iroh   With a poor stance you are unbalanced, and yo...
# 50                  Mugger                                               Ugh!
# 51                    Iroh   With a solid stance, you are a much more seri...
# 52                  Mugger   So you really think I could be a good masseur...
# 54                    Iroh                                         Of course!
# 55                  Mugger   This is so great! No one has ever believed in...
# 56                    Iroh   Happy Birthday my son.  If only I could have ...
# 58                    Aang           Hey there, fella. You look hungry.  Ahh!
# 59               Zookeeper   Hm! They are hungry. The Dai Li won't give me...
# 60                    Aang                       What kind of animal is that?
# 61               Zookeeper   Oh, that's rabbiroo. I wish I could get her a...
# 62                    Aang                                       Let's do it!
# 63               Zookeeper                                         Say again?
# 64                    Aang   There's a big open space right outside the wa...
# 65               Zookeeper   But how are you gonna transport all these wil...
# 66                    Aang               Don't worry. I'm great with animals.
# 67        Cabbage Merchant                       MY CABB--  --oh, forget it!(
# 68                    Aang                This was so much easier in my head!
# 69               Zookeeper                        But you  to open this gate!
# 70                 Guard 1                                           Or what?
# 71               Zookeeper                                           Or that!
# 72                 Guard 2                                     Open the gate!
# 73                    Aang   Well, Mr. Zookeeper, how do you like your new...
# 74               Zookeeper   Excellent job, Avatar. You should think about...
# 75           Child visitor    Mommy, Ms. Snowflake got out of the house ag...
# 76           Adult Visitor         Fluffykins  What are you doing down there?
# 77               Zookeeper   On second thought,  you should probably stick...
# 78                    Aang
# 79                   Sokka                                       What's this?
# 80        Student on stage   Through all the long night, winter moon glows...
# 81                   Sokka                                       Ahh, poetry.
# 82                Students                                              Oooh!
# 83                   Sokka   I am so sorry. Something struck me in the rea...
# 84                Students
# 85       Madame Macmu-Ling    Five seven then five, syllables mark a Haiku...
# 86                   Sokka    They call me Sokka, that is in the Water Tri...
# 87       Madame Macmu-Ling   Chittering monkey, in the spring he climbs tr...
# 88                Students                                             Ooooh.
# 89                   Sokka   You think you're so smart, with your fancy li...
# 90                Students                                             Ooooh!
# 91       Madame Macmu-Ling    Whole seasons are spent mastering the form, ...
# 92                   Sokka   I calls it easy! Like I paddle my canoe,  I'l...
# 93                Students
# 94       Madame Macmu-Ling   There's nuts and there's fruits,  in fall the...
# 95                   Sokka    Squish-squash, sling that slang. I'm always ...
# 96                Students
# 97                   Sokka    That's right I'm Sokka, it's pronounced with...
# 98                Security      Uh, that's one too many syllables there, bub.
# 99                   Sokka                                        ...poetry.r
# 100                   Zuko   Uncle, we have a problem.  One of the custome...
# 101                   Iroh    You're right Zuko. I've seen that girl in he...
# 102                   Zuko                                             What?!
# 103                    Jin          Thank you for the tea.  What's your name?
# 104                   Zuko     My name's Lee. My Uncle and I just moved here.
# 105                    Jin   Hi Lee, my name is Jin. Thank you and, well, ...
# 106                   Iroh                                      He'd love to!
# 107                    Jin   Hey. Well, look at you.  You look so cute!  G...
# 109                   Zuko        It took my Uncle ten minutes to do my hair.
# 110                    Jin               So, how do you like the city so far?
# 111                   Zuko                                           It's ok.
# 112                    Jin                    What do you like to do for fun?
# 113                   Zuko                                           Nothing.
# 114                 Waiter    Excuse me sir. Would you and your girlfriend...
# 115                   Zuko   You have... quite an appetite for a girl.   S...
# 117                    Jin   Um, thanks So, Lee, where were you and your U...
# 118                   Zuko   Um, well, we've been traveling around for a l...
# 119                    Jin                Oh! Why were you traveling so much?
# 120                   Zuko        We were uh, apart of this traveling circus.
# 121                    Jin   Really? What did you do? Wait, lemme guess, y...
# 122                   Zuko                                    Yes. I juggled.
# 123                    Jin   I've always wanted to learn how to juggle. Ca...
# 124                   Zuko            Whoah! I haven't practiced for awhile.
# 125                    Jin   I'm so excited for you to see the firelight f...
# 128                   Zuko   Ok. Now you can look.  Close your eyes and do...
# 130                    Jin   Oh wow...  What happened? How did they light?...
# 131                   Zuko   I brought you something. It's a coupon for a ...
# 132                    Jin                             Lee, this is so sweet.
# 133                   Zuko    Don't thank me. It was my Uncle's idea. He t...
# 134                    Jin   What's wrong?  Your Uncle is a good teacher. ...
# 136                   Zuko                    It's complicated. I have to go.
# 137                   Iroh                   How was your night, Prince Zuko?
# 138                   Zuko                                       It was nice.
#
#          episode_code  word_count
# MyIndex
# 0                 215        11.0
# 1                 215         2.0
# 2                 215        14.0
# 3                 215        12.0
# 4                 215        10.0
# 5                 215         3.0
# 6                 215         3.0
# 7                 215        10.0
# 8                 215         7.0
# 9                 215        16.0
# 11                215         1.0
# 12                215        16.0
# 13                215        10.0
# 14                215         3.0
# 15                215         1.0
# 16                215         3.0
# 17                215         8.0
# 18                215        17.0
# 19                215         3.0
# 20                215         3.0
# 21                215        19.0
# 22                215         1.0
# 23                215        11.0
# 25                215        39.0
# 26                215        26.0
# 27                215         2.0
# 28                215         3.0
# 29                215        13.0
# 30                215         0.0
# 31                215         3.0
# 32                215         1.0
# 33                215        13.0
# 34                215        18.0
# 35                215         1.0
# 36                215         4.0
# 37                215        24.0
# 39                215         1.0
# 40                215         1.0
# 41                215        16.0
# 42                215        16.0
# 43                215         5.0
# 44                215         6.0
# 45                215         4.0
# 46                215         3.0
# 47                215         3.0
# 48                215        13.0
# 49                215        14.0
# 50                215         1.0
# 51                215        27.0
# 52                215        16.0
# 54                215         2.0
# 55                215        11.0
# 56                215        54.0
# 58                215         7.0
# 59                215        28.0
# 60                215         6.0
# 61                215        24.0
# 62                215         3.0
# 63                215         2.0
# 64                215        12.0
# 65                215        10.0
# 66                215         6.0
# 67                215         5.0
# 68                215         8.0
# 69                215         6.0
# 70                215         2.0
# 71                215         2.0
# 72                215         3.0
# 73                215        10.0
# 74                215        13.0
# 75                215         9.0
# 76                215         7.0
# 77                215        10.0
# 78                215         0.0
# 79                215         2.0
# 80                215        15.0
# 81                215         2.0
# 82                215         1.0
# 83                215        15.0
# 84                215         0.0
# 85                215        10.0
# 86                215        15.0
# 87                215        12.0
# 88                215         1.0
# 89                215        15.0
# 90                215         1.0
# 91                215        13.0
# 92                215        13.0
# 93                215         0.0
# 94                215        15.0
# 95                215        13.0
# 96                215         0.0
# 97                215        14.0
# 98                215         8.0
# 99                215         1.0
# 100               215        37.0
# 101               215        23.0
# 102               215         1.0
# 103               215         8.0
# 104               215        10.0
# 105               215        21.0
# 106               215         3.0
# 107               215        21.0
# 109               215        10.0
# 110               215         9.0
# 111               215         2.0
# 112               215         8.0
# 113               215         1.0
# 114               215        11.0
# 115               215        13.0
# 117               215        15.0
# 118               215        10.0
# 119               215         7.0
# 120               215         8.0
# 121               215        10.0
# 122               215         3.0
# 123               215        13.0
# 124               215         6.0
# 125               215        42.0
# 128               215        11.0
# 130               215        11.0
# 131               215        13.0
# 132               215         5.0
# 133               215        15.0
# 134               215        22.0
# 136               215         6.0
# 137               215         6.0
# 138               215         3.0

# %%
#reset index for a final time

# %%
df_final.reset_index(drop = True, inplace = True)

# %%
df_final[df_final['episode_code'] == 215]
# Out:
#          character_list                                      dialogue_list  \
# 5423             Katara   Huh! Toph, aren't you gonna to get ready for ...
# 5424               Toph                                         I'm ready.
# 5425             Katara   You're not gonna wash up? You've got a little...
# 5426               Toph   You call it dirt. I call it a healthy coating...
# 5427             Katara     Hmmm. You know what we need? A girl's day out!
# 5428               Toph                                          Do I  to?
# 5429             Katara                                      It'll be fun.
# 5430               Toph   The Fancy Lady Day Spa? Sounds like my kinda ...
# 5431             Katara          Are you ready for some serious pampering?
# 5432               Toph   Arrrr! Rrrrr! Errrr!  Sure Katara, whatever y...
# 5433    Toph and Katara                                            Hahaha!
# 5434               Toph   Well, that wasn't so bad. I'm not usually int...
# 5435             Katara    I'm glad, it's about time we did something f...
# 5436      1st Mean Girl                                Wow, great makeup.
# 5437               Toph                                            Thanks.
# 5438      1st Mean Girl                                       For a clown!
# 5439             Katara     Don't listen to them, let's just keep walking.
# 5440               Star   I think she looks cute. Like that time we put...
# 5441      3rd Mean Girl                                    Good one, Star!
# 5442             Katara                                     Let's go Toph.
# 5443               Toph   No, no. That  a good one! "Like your poodle-m...
# 5444              Girls                                              Ahhh!
# 5445             Katara   Those girls don't know what they're talking a...
# 5446               Toph   It's ok. One of the good things about being b...
# 5447             Katara   That's what I really admire about you, Toph. ...
# 5448               Toph                                              I am?
# 5449             Katara                                     Yeah. You are.
# 5450               Toph   I'd return the compliment, but I have no idea...
# 5451             Katara
# 5452               Toph                                Thank you, Katara.
# 5453             Katara                                                Ow!
# 5454           Merchant   If this is for a romantic picnic, may I sugge...
# 5455               Iroh   No, it is not a romantic picnic, but it is a ...
# 5456              Child                                              Wahh!
# 5457              Woman                               Shhh. It's ok. Shhh.
# 5458               Iroh   Yeowch!  Leaves from the vine, falling so slo...
# 5459              Child                                            Hahaha!
# 5460          Angry Man                                               Hey!
# 5461               Iroh   It is usually best to admit mistakes when the...
# 5462          Angry Man   When I am through with you kids, the window w...
# 5463               Iroh                           -but not this time. Run!
# 5464             Mugger                       You. Give me all your money!
# 5465               Iroh                                What are you doing?
# 5466             Mugger                                   I'm mugging you!
# 5467               Iroh                                  With that stance?
# 5468             Mugger   Wha- What are you talking about? Just give me...
# 5469               Iroh   With a poor stance you are unbalanced, and yo...
# 5470             Mugger                                               Ugh!
# 5471               Iroh   With a solid stance, you are a much more seri...
# 5472             Mugger   So you really think I could be a good masseur...
# 5473               Iroh                                         Of course!
# 5474             Mugger   This is so great! No one has ever believed in...
# 5475               Iroh   Happy Birthday my son.  If only I could have ...
# 5476               Aang           Hey there, fella. You look hungry.  Ahh!
# 5477          Zookeeper   Hm! They are hungry. The Dai Li won't give me...
# 5478               Aang                       What kind of animal is that?
# 5479          Zookeeper   Oh, that's rabbiroo. I wish I could get her a...
# 5480               Aang                                       Let's do it!
# 5481          Zookeeper                                         Say again?
# 5482               Aang   There's a big open space right outside the wa...
# 5483          Zookeeper   But how are you gonna transport all these wil...
# 5484               Aang               Don't worry. I'm great with animals.
# 5485   Cabbage Merchant                       MY CABB--  --oh, forget it!(
# 5486               Aang                This was so much easier in my head!
# 5487          Zookeeper                        But you  to open this gate!
# 5488            Guard 1                                           Or what?
# 5489          Zookeeper                                           Or that!
# 5490            Guard 2                                     Open the gate!
# 5491               Aang   Well, Mr. Zookeeper, how do you like your new...
# 5492          Zookeeper   Excellent job, Avatar. You should think about...
# 5493      Child visitor    Mommy, Ms. Snowflake got out of the house ag...
# 5494      Adult Visitor         Fluffykins  What are you doing down there?
# 5495          Zookeeper   On second thought,  you should probably stick...
# 5496               Aang
# 5497              Sokka                                       What's this?
# 5498   Student on stage   Through all the long night, winter moon glows...
# 5499              Sokka                                       Ahh, poetry.
# 5500           Students                                              Oooh!
# 5501              Sokka   I am so sorry. Something struck me in the rea...
# 5502           Students
# 5503  Madame Macmu-Ling    Five seven then five, syllables mark a Haiku...
# 5504              Sokka    They call me Sokka, that is in the Water Tri...
# 5505  Madame Macmu-Ling   Chittering monkey, in the spring he climbs tr...
# 5506           Students                                             Ooooh.
# 5507              Sokka   You think you're so smart, with your fancy li...
# 5508           Students                                             Ooooh!
# 5509  Madame Macmu-Ling    Whole seasons are spent mastering the form, ...
# 5510              Sokka   I calls it easy! Like I paddle my canoe,  I'l...
# 5511           Students
# 5512  Madame Macmu-Ling   There's nuts and there's fruits,  in fall the...
# 5513              Sokka    Squish-squash, sling that slang. I'm always ...
# 5514           Students
# 5515              Sokka    That's right I'm Sokka, it's pronounced with...
# 5516           Security      Uh, that's one too many syllables there, bub.
# 5517              Sokka                                        ...poetry.r
# 5518               Zuko   Uncle, we have a problem.  One of the custome...
# 5519               Iroh    You're right Zuko. I've seen that girl in he...
# 5520               Zuko                                             What?!
# 5521                Jin          Thank you for the tea.  What's your name?
# 5522               Zuko     My name's Lee. My Uncle and I just moved here.
# 5523                Jin   Hi Lee, my name is Jin. Thank you and, well, ...
# 5524               Iroh                                      He'd love to!
# 5525                Jin   Hey. Well, look at you.  You look so cute!  G...
# 5526               Zuko        It took my Uncle ten minutes to do my hair.
# 5527                Jin               So, how do you like the city so far?
# 5528               Zuko                                           It's ok.
# 5529                Jin                    What do you like to do for fun?
# 5530               Zuko                                           Nothing.
# 5531             Waiter    Excuse me sir. Would you and your girlfriend...
# 5532               Zuko   You have... quite an appetite for a girl.   S...
# 5533                Jin   Um, thanks So, Lee, where were you and your U...
# 5534               Zuko   Um, well, we've been traveling around for a l...
# 5535                Jin                Oh! Why were you traveling so much?
# 5536               Zuko        We were uh, apart of this traveling circus.
# 5537                Jin   Really? What did you do? Wait, lemme guess, y...
# 5538               Zuko                                    Yes. I juggled.
# 5539                Jin   I've always wanted to learn how to juggle. Ca...
# 5540               Zuko            Whoah! I haven't practiced for awhile.
# 5541                Jin   I'm so excited for you to see the firelight f...
# 5542               Zuko   Ok. Now you can look.  Close your eyes and do...
# 5543                Jin   Oh wow...  What happened? How did they light?...
# 5544               Zuko   I brought you something. It's a coupon for a ...
# 5545                Jin                             Lee, this is so sweet.
# 5546               Zuko    Don't thank me. It was my Uncle's idea. He t...
# 5547                Jin   What's wrong?  Your Uncle is a good teacher. ...
# 5548               Zuko                    It's complicated. I have to go.
# 5549               Iroh                   How was your night, Prince Zuko?
# 5550               Zuko                                       It was nice.
#
#       episode_code  word_count
# 5423           215        11.0
# 5424           215         2.0
# 5425           215        14.0
# 5426           215        12.0
# 5427           215        10.0
# 5428           215         3.0
# 5429           215         3.0
# 5430           215        10.0
# 5431           215         7.0
# 5432           215        16.0
# 5433           215         1.0
# 5434           215        16.0
# 5435           215        10.0
# 5436           215         3.0
# 5437           215         1.0
# 5438           215         3.0
# 5439           215         8.0
# 5440           215        17.0
# 5441           215         3.0
# 5442           215         3.0
# 5443           215        19.0
# 5444           215         1.0
# 5445           215        11.0
# 5446           215        39.0
# 5447           215        26.0
# 5448           215         2.0
# 5449           215         3.0
# 5450           215        13.0
# 5451           215         0.0
# 5452           215         3.0
# 5453           215         1.0
# 5454           215        13.0
# 5455           215        18.0
# 5456           215         1.0
# 5457           215         4.0
# 5458           215        24.0
# 5459           215         1.0
# 5460           215         1.0
# 5461           215        16.0
# 5462           215        16.0
# 5463           215         5.0
# 5464           215         6.0
# 5465           215         4.0
# 5466           215         3.0
# 5467           215         3.0
# 5468           215        13.0
# 5469           215        14.0
# 5470           215         1.0
# 5471           215        27.0
# 5472           215        16.0
# 5473           215         2.0
# 5474           215        11.0
# 5475           215        54.0
# 5476           215         7.0
# 5477           215        28.0
# 5478           215         6.0
# 5479           215        24.0
# 5480           215         3.0
# 5481           215         2.0
# 5482           215        12.0
# 5483           215        10.0
# 5484           215         6.0
# 5485           215         5.0
# 5486           215         8.0
# 5487           215         6.0
# 5488           215         2.0
# 5489           215         2.0
# 5490           215         3.0
# 5491           215        10.0
# 5492           215        13.0
# 5493           215         9.0
# 5494           215         7.0
# 5495           215        10.0
# 5496           215         0.0
# 5497           215         2.0
# 5498           215        15.0
# 5499           215         2.0
# 5500           215         1.0
# 5501           215        15.0
# 5502           215         0.0
# 5503           215        10.0
# 5504           215        15.0
# 5505           215        12.0
# 5506           215         1.0
# 5507           215        15.0
# 5508           215         1.0
# 5509           215        13.0
# 5510           215        13.0
# 5511           215         0.0
# 5512           215        15.0
# 5513           215        13.0
# 5514           215         0.0
# 5515           215        14.0
# 5516           215         8.0
# 5517           215         1.0
# 5518           215        37.0
# 5519           215        23.0
# 5520           215         1.0
# 5521           215         8.0
# 5522           215        10.0
# 5523           215        21.0
# 5524           215         3.0
# 5525           215        21.0
# 5526           215        10.0
# 5527           215         9.0
# 5528           215         2.0
# 5529           215         8.0
# 5530           215         1.0
# 5531           215        11.0
# 5532           215        13.0
# 5533           215        15.0
# 5534           215        10.0
# 5535           215         7.0
# 5536           215         8.0
# 5537           215        10.0
# 5538           215         3.0
# 5539           215        13.0
# 5540           215         6.0
# 5541           215        42.0
# 5542           215        11.0
# 5543           215        11.0
# 5544           215        13.0
# 5545           215         5.0
# 5546           215        15.0
# 5547           215        22.0
# 5548           215         6.0
# 5549           215         6.0
# 5550           215         3.0

# %%
df_final.to_csv('ATLA_full_script.csv')

# %%
#Next Steps... 
#where I need to clearn things ... 

# <u
# </b>

#dashes
# other special charcter?s

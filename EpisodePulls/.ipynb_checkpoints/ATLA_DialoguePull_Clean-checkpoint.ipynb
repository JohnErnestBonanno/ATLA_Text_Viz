# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

#optional setting 
#pd.set_option('display.max_rows', 150)

# %%
season_episode_list =[]

for season in range(1,4):
    if season != 3:
        for episode in range(1,21):
            ep_num = str(episode)
            if len(ep_num) <= 1:
                ep_num = str(0)+ep_num
            else: 
                ep_num
            se_ep = str(season) + ep_num
            season_episode_list.append(se_ep)
    else:
        for episode in range(1,22):
            ep_num = str(episode)
            if len(ep_num) <= 1:
                ep_num = str(0)+ep_num
            else: 
                ep_num
            se_ep = str(season) + ep_num
            season_episode_list.append(se_ep)

# %%
season_episode_list

# %%
def getTitle(x):
    url_base = 'http://atla.avatarspirit.net/transcripts.php?num='
    season_episode_num = str(x) # in a function make this x
    response = requests.get(url_base + season_episode_num)
    
    #
    soup = BeautifulSoup(response.content, 'lxml')
    content = soup.find(class_='content')
    title = content.find(class_='welcome')
    title = title.get_text()
    title = title.split("-")[-1].strip()
    #print(title)
    return(title)

# %%
df = pd.DataFrame(columns = ['SeasonEpisodeCode','Title'])

# %%
#populate a df with SeasonEpisodeCodes & Titles
title_list = []
for x in season_episode_list:
    title_list.append(getTitle(x))

# %%
#creation of df frame
df['SeasonEpisodeCode'] = season_episode_list
df['Title'] = title_list

df['Season'] = df['SeasonEpisodeCode']
df['EpisodeNum'] = df['SeasonEpisodeCode']

#obtain season#
def seasonNum(x):
    return(int(str(x)[0]))
#apply SeasonNum to df
df['Season'] = df['Season'].apply(seasonNum)

#obtain episode #
def episodeNum(x):
    return(int(str(x)[-2:]))
#apply EpisodeNum to df
df['EpisodeNum'] = df['EpisodeNum'].apply(episodeNum)

# %%
scriptClean(104)

# %%
df

# %%
#get episode text for cleaning
def RawScriptPull(x):
    url_base = 'http://atla.avatarspirit.net/transcripts.php?num='
    season_episode_num = str(x) # in a function make this x
    response = requests.get(url_base + season_episode_num)
    
    soup = BeautifulSoup(response.content, 'lxml')
    content = soup.find(class_='content')
    raw_script = content.find(class_='content')
    
    #extracts all text in italics - which are stage directions
    for linebreak in raw_script.find_all('i'):
        linebreak.extract()
    
    #extracts all for hyperlinks - which we don't need
    for linebreak in raw_script.find_all('a'):
        linebreak.extract()
    
    #extracts all the breaks
    for linebreak in raw_script.find_all('br'):
        linebreak.extract()
    #leaves us only the bolds... which we can seperate items on
    return(str(raw_script))
    
    #file = open(str(x) + ".txt","w")
    #file.write(str(script))

# %%
#let's try doing this over two different functions

def scriptClean1(x):
    episode_code = locals()
    
    file_clean = re.sub(r'\([^()]*\)', '', RawScriptPull(x)) #references RawScriptPull so it can get cleaned 
    
    #removes data after the Ending Credits which is extra
    script = file_clean.split('[End Credits]')[0]

    #removes the data before Act I, which is also extra
    #unfortunetly, website uses 2 different conventions, so I split depending on which one it uses
    
    if "Act I</b></u>" in script:
        script_clean = script.split("Act I</b></u>")[1]
        #bold_split = script_clean.split('<b>')
    elif "Act I</u></b>" in script:
        script_clean = script.split("Act I</u></b>")[1]
        #bold_split = script_clean.split('<b>')
    return(script_clean)
    #bold_split = script_clean.split('<b>')   
    #return(bold_split)

# %%
def boldSplit(x):
    script_clean = scriptClean1(x)
    bold_split = script_clean.split('<b>') 
    return(bold_split)

# %%
#SO all of these work.... one you enter them one after the other... 

#scriptClean1(104)

#boldSplit(104)

#scriptClean2(104)

#dfConsolidateScript(101)
# Out:
#     character_list                                      dialogue_list  \
# 0            Sokka   It's not getting away from me this time. Watc...
# 1           Katara                                       Sokka, look!
# 2            Sokka    Shhh. Katara, you're gonna scare it away. Mm...
# 3           Katara                     Hey!  But Sokka! I caught one!
# 5            Sokka   Ugh! Why is it that every time you play with ...
# ..             ...                                                ...
# 158         Katara   I'm sorry, Aang. Maybe somehow there's a brig...
# 159           Aang                             I did get to meet you.
# 160         Katara   Aang? Let's head back. This place is creepy. ...
# 162           Aang      What's that you said about booby traps?  Huh?
# 166           Zuko   ...as well as his hiding place.  The last air...
#
#      episode_code  word_count
# 0             101        19.0
# 1             101         2.0
# 2             101        14.0
# 3             101         6.0
# 5             101        15.0
# ..            ...         ...
# 158           101        12.0
# 159           101         6.0
# 160           101        15.0
# 162           101         8.0
# 166           101        24.0
#
# [148 rows x 4 columns]

# %%
#creates a list of lists with both character + relevant dialogue

def scriptClean2(x):
    episode_code = locals()
    bold_split = boldSplit(x)
    master_list = []
    for x in range(len(bold_split)):
        output = bold_split[x].split(':')
        master_list.append(output)
    
    #collects all the characters who speak
    character_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            character_list.append(test.strip('</b>')) # remove the bold hyperlink to cleanup the data
    #collects what all the characters say
    dialogue_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            dialogue_list.append(holder[1].strip('</b>')) # remove the bold hyperlink to cleanup the data 
    
    
    #create a list of episode numbers to add to df (feels inefficient and should be a better way to do this)
    episode_list = []
    
    for x in range(len(character_list)):
        episode_list.append(int(episode_code['x']))
    
    dfScript = pd.DataFrame()
    
    dfScript['episode_code'] = episode_list
    
    dfScript['character_list'] = character_list
    dfScript['dialogue_list'] = dialogue_list
    
    count = dfScript['dialogue_list'].str.split().str.len()
    count = list(count)
    dfScript['word_count']=count

    return(dfScript)

# %%
#creating a function to clean the script
#then puts it into a data frame
#and counts the number of words each character says

def scriptClean(x):
    episode_code = locals()
    
    file_clean = re.sub(r'\([^()]*\)', '', RawScriptPull(x)) #references RawScriptPull so it can get cleaned 
    
    #removes data after the Ending Credits which is extra
    script = file_clean.split('[End Credits]')[0]

    #removes the data before Act I, which is also extra
    #unfortunetly, website uses 2 different conventions, so I split depending on which one it uses
    
    if "Act I</b></u>" in script:
        script_clean = script.split("Act I</b></u>")[1]
        #bold_split = script_clean.split('<b>')
    elif "Act I</u></b>" in script:
        script_clean = script.split("Act I</u></b>")[1]
        #bold_split = script_clean.split('<b>')
    #return(script_clean)
    bold_split = script_clean.split('<b>')
    
    #creates a list of lists with both character + relevant dialogue
    master_list = []
    for x in range(len(bold_split)):
        output = bold_split[x].split(':')
        master_list.append(output)
    
    #collects all the characters who speak
    character_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            character_list.append(test.strip('</b>')) # remove the bold hyperlink to cleanup the data
    #collects what all the characters say
    dialogue_list = []

    for x in range(len(master_list)):
        holder = master_list[x]
        if len(holder)>1:
            test = holder[0].strip()
            dialogue_list.append(holder[1].strip('</b>')) # remove the bold hyperlink to cleanup the data 
    
    
    #create a list of episode numbers to add to df (feels inefficient and should be a better way to do this)
    episode_list = []
    
    for x in range(len(character_list)):
        episode_list.append(int(episode_code['x']))
    
    dfScript = pd.DataFrame()
    
    dfScript['episode_code'] = episode_list
    
    dfScript['character_list'] = character_list
    dfScript['dialogue_list'] = dialogue_list
    
    count = dfScript['dialogue_list'].str.split().str.len()
    count = list(count)
    dfScript['word_count']=count

    return(dfScript)

# %%
test = season_episode_list[:4]

# %%
# the fact that this works, suggests that somethign else is going on... 

for i in test:
    print(dfConsolidateScript(i))
    #print(i)
# Out:
#     character_list                                      dialogue_list  \
# 0            Sokka   It's not getting away from me this time. Watc...
# 1           Katara                                       Sokka, look!
# 2            Sokka    Shhh. Katara, you're gonna scare it away. Mm...
# 3           Katara                     Hey!  But Sokka! I caught one!
# 5            Sokka   Ugh! Why is it that every time you play with ...
# ..             ...                                                ...
# 158         Katara   I'm sorry, Aang. Maybe somehow there's a brig...
# 159           Aang                             I did get to meet you.
# 160         Katara   Aang? Let's head back. This place is creepy. ...
# 162           Aang      What's that you said about booby traps?  Huh?
# 166           Zuko   ...as well as his hiding place.  The last air...
#
#      episode_code  word_count
# 0             101        19.0
# 1             101         2.0
# 2             101        14.0
# 3             101         6.0
# 5             101        15.0
# ..            ...         ...
# 158           101        12.0
# 159           101         6.0
# 160           101        15.0
# 162           101         8.0
# 166           101        24.0
#
# [148 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0         Children                                  Yay! Aang's back!
# 1            Sokka   I knew it! You signaled the Fire Navy with th...
# 2           Katara       Aang didn't do anything. It was an accident.
# 3             Aang   Yeh, we were on the ship and there was this b...
# 4        Gran Gran   Katara, you shouldn't have gone on that ship....
# ..             ...                                                ...
# 122          Sokka               I'd like that. I'd really like that.
# 123         Katara                       Then we're in this together.
# 124           Aang   All right, but before I learn waterbending, w...
# 125         Katara                                      What's there?
# 126           Aang   Here  we'll ride the hopping llamas. Then waa...
#
#      episode_code  word_count
# 0             102         3.0
# 1             102        19.0
# 2             102         8.0
# 3             102        19.0
# 4             102        15.0
# ..            ...         ...
# 122           102         7.0
# 123           102         5.0
# 124           102        19.0
# 125           102         2.0
# 126           102        39.0
#
# [109 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0             Aang    Wait 'til you see it, Katara. The Air Temple...
# 1           Katara    Aang, I know you're excited, but it's been a...
# 2             Aang                         That's why I'm so excited!
# 3           Katara   It's just that a lot can change in all that t...
# 4             Aang   Wake up, Sokka! Air Temple here we come!  I k...
# ..             ...                                                ...
# 198           Aang           Looks like you made a new friend, Sokka.
# 199          Sokka                              Can't talk. Must eat.
# 200           Aang   You, me, and Appa.  We're all that's left of ...
# 203         Katara                    What are you going to name him?
# 204           Aang                                              Momo.
#
#      episode_code  word_count
# 0             103        19.0
# 1             103        15.0
# 2             103         5.0
# 3             103        11.0
# 4             103        18.0
# ..            ...         ...
# 198           103         8.0
# 199           103         4.0
# 200           103        21.0
# 203           103         7.0
# 204           103         1.0
#
# [166 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0             Zuko    The only reason you should be interrupting m...
# 1             Iroh    Well, there is news, Prince Zuko, but you mi...
# 2             Zuko    Uncle, you taught me that keeping a level he...
# 3             Iroh        Okay, then... we have no idea where he is.
# 4             Zuko                                             WHAT?!
# ..             ...                                                ...
# 202           Zuko        Back to the ship! Don't lose sight of them!
# 203         Katara    What are you doing?!  I know it's hard, but ...
# 205          Oyagi                                 Thank you, Avatar.
# 206           Aang     I know, I know. That was stupid and dangerous.
# 207         Katara                                       Yes, it was.
#
#      episode_code  word_count
# 0             104        16.0
# 1             104        16.0
# 2             104        29.0
# 3             104         9.0
# 4             104         1.0
# ..            ...         ...
# 202           104         9.0
# 203           104        31.0
# 205           104         3.0
# 206           104         9.0
# 207           104         3.0
#
# [196 rows x 4 columns]
#        character_list                                      dialogue_list  \
# 0                Aang   I used to always come here to visit my friend...
# 2              Katara   Wow. We don't have cities like this in the So...
# 3               Sokka          They have buildings here that don't melt!
# 4                Aang   Well, let's go slow pokes! The real fun is in...
# 5              Katara   Wait, Aang! It could be dangerous if people f...
# ..                ...                                                ...
# 152         King Bumi               Who you calling old?  Okay. I'm old.
# 153             Sokka   Why did you do all this instead of just telli...
# 154         King Bumi   First of all, it's pretty fun messing with pe...
# 155              Aang   Thank you for your wisdom. But before we leav...
# 156  Cabbage Merchant                                       My cabbages!
#
#      episode_code  word_count
# 0             105        17.0
# 2             105        11.0
# 3             105         7.0
# 4             105        12.0
# 5             105        13.0
# ..            ...         ...
# 152           105         7.0
# 153           105        14.0
# 154           105       105.0
# 155           105        15.0
# 156           105         2.0
#
# [129 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0             Aang           Great, you're back! What's for dinner?\r
# 1            Sokka   We've got a few options. First, round nuts an...
# 2           Katara                  Seriously, what else ya got?\r
# 3            Sokka                               What was that!?\r
# 4             Aang                  It's coming from over there!\r
# ..             ...                                                ...
# 183           Tyro   Yes, to take back my village.  To take back A...
# 184           Haru                                    Come with us.\r
# 185         Katara   I can't. Your mission is to take back your ho...
# 186           Haru   That's him, isn't it? The Avatar. Katara, tha...
# 187         Katara   I know.  My mother's necklace! It's gone!\r
#
#      episode_code  word_count
# 0             106         6.0
# 1             106        27.0
# 2             106         5.0
# 3             106         3.0
# 4             106         5.0
# ..            ...         ...
# 183           106        26.0
# 184           106         3.0
# 185           106        19.0
# 186           106        30.0
# 187           106         7.0
#
# [171 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0           Katara   Those clouds look so soft, don't they? Like y...
# 1            Sokka                    Maybe you should give it a try.
# 2           Katara                                  You're hilarious.
# 3             Aang   Turns out clouds are made of water!  I'll try...
# 5           Katara                                 Hey, what is that?
# ..             ...                                                ...
# 160         Katara                                      That's great!
# 161          Sokka                                 Creepy, but great.
# 162           Aang   There's a temple on a crescent shaped island,...
# 163         Katara                     But, the solstice is tomorrow.
# 164           Aang   Yeh, and there's one more problem. The island...
#
#      episode_code  word_count
# 0             107        22.0
# 1             107         7.0
# 2             107         2.0
# 3             107        11.0
# 5             107         4.0
# ..            ...         ...
# 160           107         2.0
# 161           107         3.0
# 162           107        23.0
# 163           107         5.0
# 164           107        13.0
#
# [137 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0            Aang                      Let's go Appa! Come on, boy!\r
# 1             Appa                                      GRRRRRRR\r
# 2             Aang   Look, I'm sorry, but Katara and Sokka aren't ...
# 3            Sokka   I think his big butt is trying to tell you so...
# 4           Katara   Please don't go, Aang. The world can't afford...
# ..             ...                                                ...
# 178           Aang                            Thanks. Where's Shyu?\r
# 179         Katara                                 I don't know.\r
# 180           Zhao   No prince. No Avatar. Apparently the only thi...
# 181      Fire Sage      But Commander, only Shyu helped the Avatar.\r
# 182           Zhao   Save your stories for the Fire Lord. As far a...
#
#      episode_code  word_count
# 0             108         6.0
# 1             108         1.0
# 2             108        34.0
# 3             108        11.0
# 4             108        19.0
# ..            ...         ...
# 178           108         3.0
# 179           108         3.0
# 180           108        14.0
# 181           108         7.0
# 182           108        21.0
#
# [170 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0            Sokka   Would you sit down? If we hit a bump you'll g...
# 1             Aang   It's what Avatar Roku said. I'm supposed to m...
# 2            Sokka   Well, let's see, you've pretty much mastered ...
# 3             Aang   I haven't even started waterbending and we're...
# 4           Katara   Calm down. It's going to be okay. If you want...
# ..             ...                                                ...
# 201          Sokka                       Is that really how you feel?
# 202         Katara                                        The scroll!
# 203          Sokka                         First, what did you learn?
# 204         Katara      Stealing is wrong.  Unless it's from pirates!
# 205           Aang                            Haha! Good one, Katara.
#
#      episode_code  word_count
# 0             109        17.0
# 1             109        16.0
# 2             109        26.0
# 3             109        19.0
# 4             109        22.0
# ..            ...         ...
# 201           109         6.0
# 202           109         2.0
# 203           109         5.0
# 204           109         7.0
# 205           109         4.0
#
# [178 rows x 4 columns]
#     character_list                                      dialogue_list  \
# 0             Aang           Hang on Momo!\r     Where's Momo?\r
# 3            Sokka                   This is gonna take forever.\r
# 4             Aang                                 That works...\r
# 5            Sokka   Ah-ah...no flying this time.\r  These are Fir...
# 7           Katara                                         What?\r
# ..             ...                                                ...
# 171            Jet   We can't win without making some sacrifices.\...
# 172          Sokka   You lied to Aang and Katara about the forest ...
# 173            Jet   Because they don't understand the demands of ...
# 174          Sokka   I do understand. I understand that there's no...
# 175            Jet   I was hoping you'd have an open mind, but I c...
#
#      episode_code  word_count
# 0             110         5.0
# 3             110         5.0
# 4             110         2.0
# 5             110        22.0
# 7             110         1.0
# ..            ...         ...
# 171           110         7.0
# 172           110        10.0
# 173           110        14.0
# 174           110        16.0
# 175           110        19.0
#
# [161 rows x 4 columns]

# %%
blankList = []

# %%
for i in test:
    holder = dfConsolidateScript(i)
    blankList.append(holder)

# %%
blankList
# Out:
# [    character_list                                      dialogue_list  \
#  0            Sokka   It's not getting away from me this time. Watc...
#  1           Katara                                       Sokka, look!
#  2            Sokka    Shhh. Katara, you're gonna scare it away. Mm...
#  3           Katara                     Hey!  But Sokka! I caught one!
#  5            Sokka   Ugh! Why is it that every time you play with ...
#  ..             ...                                                ...
#  158         Katara   I'm sorry, Aang. Maybe somehow there's a brig...
#  159           Aang                             I did get to meet you.
#  160         Katara   Aang? Let's head back. This place is creepy. ...
#  162           Aang      What's that you said about booby traps?  Huh?
#  166           Zuko   ...as well as his hiding place.  The last air...
#
#       episode_code  word_count
#  0             101        19.0
#  1             101         2.0
#  2             101        14.0
#  3             101         6.0
#  5             101        15.0
#  ..            ...         ...
#  158           101        12.0
#  159           101         6.0
#  160           101        15.0
#  162           101         8.0
#  166           101        24.0
#
#  [148 rows x 4 columns],
#      character_list                                      dialogue_list  \
#  0         Children                                  Yay! Aang's back!
#  1            Sokka   I knew it! You signaled the Fire Navy with th...
#  2           Katara       Aang didn't do anything. It was an accident.
#  3             Aang   Yeh, we were on the ship and there was this b...
#  4        Gran Gran   Katara, you shouldn't have gone on that ship....
#  ..             ...                                                ...
#  122          Sokka               I'd like that. I'd really like that.
#  123         Katara                       Then we're in this together.
#  124           Aang   All right, but before I learn waterbending, w...
#  125         Katara                                      What's there?
#  126           Aang   Here  we'll ride the hopping llamas. Then waa...
#
#       episode_code  word_count
#  0             102         3.0
#  1             102        19.0
#  2             102         8.0
#  3             102        19.0
#  4             102        15.0
#  ..            ...         ...
#  122           102         7.0
#  123           102         5.0
#  124           102        19.0
#  125           102         2.0
#  126           102        39.0
#
#  [109 rows x 4 columns],
#      character_list                                      dialogue_list  \
#  0             Aang    Wait 'til you see it, Katara. The Air Temple...
#  1           Katara    Aang, I know you're excited, but it's been a...
#  2             Aang                         That's why I'm so excited!
#  3           Katara   It's just that a lot can change in all that t...
#  4             Aang   Wake up, Sokka! Air Temple here we come!  I k...
#  ..             ...                                                ...
#  198           Aang           Looks like you made a new friend, Sokka.
#  199          Sokka                              Can't talk. Must eat.
#  200           Aang   You, me, and Appa.  We're all that's left of ...
#  203         Katara                    What are you going to name him?
#  204           Aang                                              Momo.
#
#       episode_code  word_count
#  0             103        19.0
#  1             103        15.0
#  2             103         5.0
#  3             103        11.0
#  4             103        18.0
#  ..            ...         ...
#  198           103         8.0
#  199           103         4.0
#  200           103        21.0
#  203           103         7.0
#  204           103         1.0
#
#  [166 rows x 4 columns],
#      character_list                                      dialogue_list  \
#  0             Zuko    The only reason you should be interrupting m...
#  1             Iroh    Well, there is news, Prince Zuko, but you mi...
#  2             Zuko    Uncle, you taught me that keeping a level he...
#  3             Iroh        Okay, then... we have no idea where he is.
#  4             Zuko                                             WHAT?!
#  ..             ...                                                ...
#  202           Zuko        Back to the ship! Don't lose sight of them!
#  203         Katara    What are you doing?!  I know it's hard, but ...
#  205          Oyagi                                 Thank you, Avatar.
#  206           Aang     I know, I know. That was stupid and dangerous.
#  207         Katara                                       Yes, it was.
#
#       episode_code  word_count
#  0             104        16.0
#  1             104        16.0
#  2             104        29.0
#  3             104         9.0
#  4             104         1.0
#  ..            ...         ...
#  202           104         9.0
#  203           104        31.0
#  205           104         3.0
#  206           104         9.0
#  207           104         3.0
#
#  [196 rows x 4 columns]]

# %%
df_list_holder = []

for i in range(len(test)):
    print(test[i])
    script = dfConsolidateScript(i)
    df_list_holder.append(script)
# Out:
# 101
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-574cb21ecb74> in <module>
#       3 for i in range(len(test)):
#       4     print(test[i])
# ----> 5     script = dfConsolidateScript(i)
#       6     df_list_holder.append(script)
#
# <ipython-input-6-4d7e5e747670> in dfConsolidateScript(x)
#       1 def dfConsolidateScript(x):
#       2
# ----> 3     dfScript = scriptClean2(x)
#       4
#       5     i = 1
#
# <ipython-input-11-e3496aa4c0a2> in scriptClean2(x)
#       3 def scriptClean2(x):
#       4     episode_code = locals()
# ----> 5     bold_split = boldSplit(x)
#       6     master_list = []
#       7     for x in range(len(bold_split)):
#
# <ipython-input-4-77cb7b395482> in boldSplit(x)
#       1 def boldSplit(x):
# ----> 2     script_clean = scriptClean1(x)
#       3     bold_split = script_clean.split('<b>')
#       4     return(bold_split)
#
# <ipython-input-3-d34275fe1313> in scriptClean1(x)
#      18         script_clean = script.split("Act I</u></b>")[1]
#      19         #bold_split = script_clean.split('<b>')
# ---> 20     return(script_clean)
#      21     #bold_split = script_clean.split('<b>')
#      22     #return(bold_split)
#
# UnboundLocalError: local variable 'script_clean' referenced before assignment

# %%
def dfConsolidateScript(x):

    dfScript = scriptClean2(x)
    
    i = 1

    dfScriptFinal = pd.DataFrame()
    dfScriptFinal = dfScriptFinal.append(dfScript.iloc[0]) #return another function

    while i < len(dfScript.index):
        if dfScript['character_list'][i] == dfScript['character_list'][i-1]: 

            #consolidates the word count into a single value when the same characters speaks twice in a row
            word_count_consolidate = (dfScript['word_count'][i]+dfScript['word_count'][i-1])
            dfScriptFinal['word_count'].at[i-1] = word_count_consolidate 

            #consolidates the dialogue when the same character speaks twice in a row
            dialogue_consolidate = (dfScript['dialogue_list'][i]+ " " + dfScript['dialogue_list'][i-1])
            dfScriptFinal['dialogue_list'].at[i-1] = dialogue_consolidate 

            i = i + 1
        else:
            dfScriptFinal = dfScriptFinal.append(dfScript.iloc[i])
            i = i + 1
    dfScriptFinal['episode_code'] = dfScriptFinal['episode_code'].astype(int)
    return(dfScriptFinal)

# %%
scriptClean(104)

# %%
dfConsolidateScript(104)

# %%
test = season_episode_list[:4]

# %%
test

# %%
#create master data frame that aggregates all episodes & dialogue together
#pulls from episode list created in the beginning

df_list_holder = []

for i in range(len(test)):
    print(test[i])
    script = dfConsolidateScript(i)
    df_list_holder.append(script)

#df_master = pd.concat(df_list_holder)
#df_master.reset_index(drop = True, inplace = True)

# %%
dfConsolidateScript(101)

# %%
dfConsolidateScript(102)

# %%
#scriptClean1(101)
#scriptClean2(101)
#dfConsolidateScript(104)
